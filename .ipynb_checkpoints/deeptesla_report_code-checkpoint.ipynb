# %% [markdown]
# ## II. 分析
#
# ### 数据的探索

# %% [markdown]
# 加载9张图片

# %%
## Load front-roadway data
import cv2
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
# %matplotlib inline

def show_images(images, cols = 1, titles = None):
    """Display a list of images in a single figure with matplotlib.
    
    Parameters
    ---------
    images: List of np.arrays compatible with plt.imshow.
    
    cols (Default = 1): Number of columns in figure (number of rows is 
                        set to np.ceil(n_images/float(cols))).
    
    titles: List of titles corresponding to each image. Must have
            the same length as titles.
    """
    assert((titles is None)or (len(images) == len(titles)))
    n_images = len(images)
    if titles is None: titles = ['Image (%d)' % i for i in range(1,n_images + 1)]
    fig = plt.figure()
    for n, (image, title) in enumerate(zip(images, titles)):
        a = fig.add_subplot(cols, np.ceil(n_images/float(cols)), n + 1)
        if image.ndim == 2:
            plt.gray()
        plt.imshow(image)
        a.set_title(title)
    fig.set_size_inches(np.array(fig.get_size_inches()) * n_images)
    plt.show()

import random
def get_random_images():
    imgs = []
    cap = cv2.VideoCapture("./epochs/epoch01_front.mkv")
    for i in range(100):
        ret, img = cap.read()
        if(ret):
            imgs.append(img)
    cap.release()
    random_imgs = []
    for i in range(9):
        index = random.randint(0, 99)
        random_imgs.append(imgs[index])
    return random_imgs

show_images(get_random_images(),cols=3)

# %% [markdown]
# 显示CVS

# %%
import pandas as pd
wheel_sig = pd.read_csv('./epochs/epoch01_steering.csv')
wheel_sig.head()
# Out:
#            ts_micro  frame  wheel
# 0  1464650070285914      0   -1.0
# 1  1464650070319247      1   -1.0
# 2  1464650070352581      2   -1.0
# 3  1464650070385914      3   -1.0
# 4  1464650070419247      4   -1.0

# %% [markdown]
# ### 探索性可视化

# %% [markdown]
# labels可视化

# %%
wheel_sig.wheel.hist(bins=50)
wheel_sig.plot(x='frame',y='wheel')

# %% [markdown]
# ## III. 方法
#
# ### 数据预处理

# %%
import datasets
(X_train, y_train),(X_val,y_val),(X_test, y_test) = datasets.load_data()
# Out:
# Using TensorFlow backend.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-b69defc21e30> in <module>()
#       1 import datasets
# ----> 2 (X_train, y_train),(X_val,y_val),(X_test, y_test) = datasets.load_data()
#
# /Users/lintao/Desktop/资料备份/机器学习/其它资料/P6/code/deep_tesla/datasets.py in load_data()
#     147
#     148 def load_data():
# --> 149     create_h5data()
#     150     data_file = './epochs/deep_tesla.hdf5'
#     151     X_train = HDF5Matrix(data_file, 'train_images')
#
# /Users/lintao/Desktop/资料备份/机器学习/其它资料/P6/code/deep_tesla/datasets.py in create_h5data()
#      85             ret, img = cap.read()
#      86             if (ret):
# ---> 87                 images[image_index] = img
#      88                 image_index += 1
#      89             else:
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper (/Users/ilan/minonda/conda-bld/h5py_1496887972496/work/h5py/_objects.c:2846)()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper (/Users/ilan/minonda/conda-bld/h5py_1496887972496/work/h5py/_objects.c:2804)()
#
# /Users/lintao/anaconda/lib/python3.6/site-packages/h5py/_hl/dataset.py in __setitem__(self, args, val)
#     628         mspace = h5s.create_simple(mshape_pad, (h5s.UNLIMITED,)*len(mshape_pad))
#     629         for fspace in selection.broadcast(mshape):
# --> 630             self.id.write(mspace, fspace, val, mtype, dxpl=self._dxpl)
#     631
#     632     def read_direct(self, dest, source_sel=None, dest_sel=None):
#
# KeyboardInterrupt:

# %%
print(X_train.shape)
print(y_train.shape)
print(X_val.shape)
print(y_val.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (20, 200, 200, 3)
# (20,)
# (2, 200, 200, 3)
# (2,)

# %% [markdown]
# ### 执行过程

# %% [markdown]
# 英伟达模型

# %%
from keras.layers import *
from keras.models import Model
from keras import optimizers
from keras.models import model_from_json
import keras
import os
import params

weights_file = './models/nvidia-model.h5'
model_file = './models/nvidia-model.json'


if os.path.exists(model_file) and os.path.exists(weights_file):
    with open(model_file, 'r') as in_file:
        json_model = in_file.read()
        model = model_from_json(json_model)
    model.load_weights(weights_file)
    model.compile(optimizer=optimizers.Adadelta(),
                  loss='mse',
                  metrics=['mse'])
    test_loss= model.evaluate(X_test, y_test)
    print('Test loss is:{}'.format(test_loss))
else:
    inputs = Input(shape=(params.FLAGS.img_h, params.FLAGS.img_w, params.FLAGS.img_c))
    x=Lambda(lambda x:x/255.0-0.5)(inputs)
    x=Conv2D(24, (5, 5), activation="relu", strides=(2, 2), padding="valid")(x)
    x=Conv2D(36, (5, 5), activation="relu", strides=(2, 2), padding="valid")(x)
    x=Conv2D(48, (5, 5), activation="relu", strides=(2, 2), padding="valid")(x)
    x=Conv2D(64, (3, 3), activation="relu", strides=(1, 1), padding="valid")(x)
    x=Conv2D(64, (3, 3), activation="relu", strides=(1, 1), padding="valid")(x)
    x=Flatten()(x)
    x=Dense(1164, activation='relu')(x)
    x=Dense(100, activation='relu')(x)
    x=Dense(50, activation='relu')(x)
    x=Dense(10, activation='relu')(x)
    outputs=Dense(1, activation='tanh')(x)
    model = Model(inputs=inputs,outputs=outputs)
    model.compile(optimizer=optimizers.Adadelta(),
                  loss='mse',
                  metrics=['mse'])
    model.fit(x=X_train,y=y_train,epochs=1,validation_data=(val_imgs,val_labels),shuffle="batch")
    model.save_weights(weights_file)
    with open(model_file, 'w') as f:
        f.write(model.to_json())
    test_loss= model.evaluate(X_test, y_test)
    print('Test loss is:{}'.format(test_loss))
# Out:
# 2/2 [==============================] - 0s
# Test loss is:[0.23942086100578308, 0.23942086100578308]
