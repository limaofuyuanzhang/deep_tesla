# %%
import cv2
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
import pylab

## Load front-roadway data
cap = cv2.VideoCapture('./epochs/epoch01_front.mkv')
ret, img = cap.read()
print(ret)
cap.release()
## Show
plt.imshow(img)
pylab.show()
# Out:
# True

# %%
## The size of the images
img.shape
# Out:
# (720, 1280, 3)

# %%
import datasets
img1 = datasets.img_change_brightness(img)

# %%
plt.imshow(img1)
pylab.show()

# %%
def img_horizontal_flip(img):
    img = img[:,::-1,:]
    return img

# %%
img2=img_horizontal_flip(img)
plt.imshow(img2)
pylab.show()
# Out:
# [156 157 157 157 157 158 158 158 158 158]
# [249 249 249 249 249 249 249 249 249 249]

# %%
import pandas as pd
## Load wheel signal data
wheel_sig = pd.read_csv('./epochs/epoch01_steering.csv')
print(wheel_sig.shape)
## Show
wheel_sig.head()
# Out:
# (1500, 3)
#            ts_micro  frame  wheel
# 0  1464650070285914      0   -1.0
# 1  1464650070319247      1   -1.0
# 2  1464650070352581      2   -1.0
# 3  1464650070385914      3   -1.0
# 4  1464650070419247      4   -1.0

# %%
## Distribution of wheel signal
wheel_sig.wheel.hist(bins=50)
pylab.show()

# %%
# 读取所有的数据
def load_train():
    cap = cv2.VideoCapture('./epochs/epoch01_front.mkv')
ret, img = cap.read()
